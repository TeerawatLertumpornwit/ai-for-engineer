# %% [markdown]
# # **Lab 1.1 : Multilayer Perceptron (MLP)**

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.17.0'

# %% [markdown]
# ## **Step 1: Import library**

# %%
import numpy as np
from numpy.random import seed
seed(42)
import tensorflow as tf


from tensorflow.keras.layers import Dense,Input, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras import Model
import matplotlib.pyplot as plt

# %%
nb_epochs = 35
batch_size = 32
nb_classes = 10
class_name = {
    0: 'airplane',
    1: 'automobile',
    2: 'bird',
    3: 'cat',
    4: 'deer',
    5: 'dog',
    6: 'frog',
    7: 'horse',
    8: 'ship',
    9: 'truck',
}

# %%
cifar = tf.keras.datasets.cifar10

# %% [markdown]
# ## **Step 2: Load data**

# %%
(x_train,y_train),(x_test,y_test) = cifar.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0

# %%
x_train.shape
# Out:
# (50000, 32, 32, 3)

# %%
y_train.shape
# Out:
# (50000,)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ## **Step 3: Visualize example data**

# %%
def draw_img(i):
    im = x_train[i]
    c = y_train[i]
    plt.imshow(im)
    plt.title("Class %d (%s)" % (c, class_name[c]))
    plt.axis('on')

def draw_sample(X, y, n, rows=4, cols=4, imfile=None, fontsize=12):
    for i in range(0, rows*cols):
        plt.subplot(rows, cols, i+1)
        im = X[n+i].reshape(32,32,3)
        plt.imshow(im, cmap=plt.cm.binary)
        plt.title("{}".format(class_name[y[n+i]]), fontsize=fontsize)
        plt.axis('off')
        plt.subplots_adjust(wspace=0.6, hspace=0.01)

# %%
draw_img(7)

# %%
draw_sample(x_train, y_train, 0, 3, 5)

# %% [markdown]
# ## **Step 4: Create Multilayer Perceptron Model**
#
# > Dense layers are keras alias for Fully connected layers. These layers give the ability to classify the features learned by the CNN.

# %% [markdown]
# Overfit

# %%
input = Input(shape = (32,32,3))
x = Flatten()(input)
x = Dense(32, activation='relu')(x)
prediction = Dense(10, activation='softmax')(x)
model = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ## **Step 5: Loss,  Optimizer, Early stopping**

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=2, min_lr=1e-6)
model.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## **Step 6: Fit model**

# %%
h = model.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.1051 - loss: 2.3101 - val_accuracy: 0.0999 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 2/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 2ms/step - accuracy: 0.0989 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 3/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.0981 - loss: 2.3028 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 4/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0979 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 0.0010
# Epoch 5/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0992 - loss: 2.3027 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 2.0000e-04
# Epoch 6/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1027 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 2.0000e-04
# Epoch 7/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0998 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 2.0000e-04
# Epoch 8/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0994 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 4.0000e-05
# Epoch 9/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0988 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 4.0000e-05
# Epoch 10/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0985 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 8.0000e-06
# Epoch 11/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.1016 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 8.0000e-06
# Epoch 12/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1016 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.6000e-06
# Epoch 13/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1006 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.6000e-06
# Epoch 14/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1001 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 15/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0990 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 16/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1008 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 17/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0989 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 18/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1004 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 19/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0996 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 20/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0998 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 21/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1000 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 22/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1016 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 23/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.0975 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 24/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1015 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 25/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0999 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 26/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1026 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 27/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.0997 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 28/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.1020 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 29/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1003 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 30/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1002 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 31/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.1014 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 32/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.1010 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 33/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.0999 - loss: 2.3026 - val_accuracy: 0.1000 - val_loss: 2.3026 - learning_rate: 1.0000e-06
# Epoch 33: early stopping

# %% [markdown]
# ## **Step 7: Plot loss and accuracy**

# %%
history_dict = h.history
history_dict.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
loss_values = history_dict['loss']
val_loss_values = history_dict['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict['accuracy']
val_acc_values = history_dict['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
lr_values = history_dict['learning_rate']

plt.plot(epochs, lr_values, 'bo')
plt.title('Learning rate')
plt.xlabel('Epochs')
plt.ylabel('Learning rate')

plt.show()

# %% [markdown]
# ## **Step 8: Evaluate**

# %%
loss, accuracy = model.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.100000  ;  loss = 2.302587

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.100000  ;  loss = 2.302585

# %% [markdown]
# ## **Step 9 : Confusion matrix**

# %%
from sklearn.metrics import confusion_matrix
import itertools
def plot_confusion_matrix(cm, classes,normalize=False,title='Confusion matrix',cmap=plt.cm.Blues):

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes)
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # **Lab 1.2 : Add Dropout**

# %% [markdown]
# ## **Step 10 : Add Dropout**
#
# > Dropout is the method used to reduce overfitting. It forces the model to learn multiple independent representations of the same data by randomly disabling neurons in the learning phase. In our model, dropout will randomnly disable 20% of the neurons.

# %%
input = Input(shape = (32,32,3))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
x = Dense(256, activation = 'relu')(x)
prediction = Dense(10, activation='softmax')(x)
model_2 = Model(inputs = input, outputs = prediction)

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='loss', factor=0.2,patience=2, min_lr=1e-6)
model_2.compile(optimizer='Adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
h_2 = model_2.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 8s 4ms/step - accuracy: 0.2410 - loss: 2.0869 - val_accuracy: 0.3505 - val_loss: 1.8081 - learning_rate: 0.0010
# Epoch 2/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3265 - loss: 1.8489 - val_accuracy: 0.3611 - val_loss: 1.7570 - learning_rate: 0.0010
# Epoch 3/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3472 - loss: 1.7880 - val_accuracy: 0.4003 - val_loss: 1.6903 - learning_rate: 0.0010
# Epoch 4/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.3635 - loss: 1.7491 - val_accuracy: 0.4144 - val_loss: 1.6712 - learning_rate: 0.0010
# Epoch 5/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.3828 - loss: 1.7244 - val_accuracy: 0.4122 - val_loss: 1.6507 - learning_rate: 0.0010
# Epoch 6/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.3820 - loss: 1.7034 - val_accuracy: 0.4191 - val_loss: 1.6354 - learning_rate: 0.0010
# Epoch 7/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.3916 - loss: 1.6933 - val_accuracy: 0.4260 - val_loss: 1.6220 - learning_rate: 0.0010
# Epoch 8/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3929 - loss: 1.6824 - val_accuracy: 0.4284 - val_loss: 1.6243 - learning_rate: 0.0010
# Epoch 9/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.3940 - loss: 1.6733 - val_accuracy: 0.4060 - val_loss: 1.6336 - learning_rate: 0.0010
# Epoch 10/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.3967 - loss: 1.6676 - val_accuracy: 0.4279 - val_loss: 1.6004 - learning_rate: 0.0010
# Epoch 11/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4002 - loss: 1.6607 - val_accuracy: 0.4246 - val_loss: 1.5961 - learning_rate: 0.0010
# Epoch 12/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4024 - loss: 1.6521 - val_accuracy: 0.4441 - val_loss: 1.5696 - learning_rate: 0.0010
# Epoch 13/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4101 - loss: 1.6436 - val_accuracy: 0.4368 - val_loss: 1.5823 - learning_rate: 0.0010
# Epoch 14/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4130 - loss: 1.6396 - val_accuracy: 0.4371 - val_loss: 1.5815 - learning_rate: 0.0010
# Epoch 15/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.4142 - loss: 1.6181 - val_accuracy: 0.4441 - val_loss: 1.5807 - learning_rate: 0.0010
# Epoch 16/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4180 - loss: 1.6178 - val_accuracy: 0.4498 - val_loss: 1.5593 - learning_rate: 0.0010
# Epoch 17/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4194 - loss: 1.6197 - val_accuracy: 0.4423 - val_loss: 1.5812 - learning_rate: 0.0010
# Epoch 18/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4181 - loss: 1.6200 - val_accuracy: 0.4280 - val_loss: 1.6091 - learning_rate: 0.0010
# Epoch 19/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4200 - loss: 1.6077 - val_accuracy: 0.4512 - val_loss: 1.5504 - learning_rate: 0.0010
# Epoch 20/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4250 - loss: 1.6015 - val_accuracy: 0.4496 - val_loss: 1.5576 - learning_rate: 0.0010
# Epoch 21/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4224 - loss: 1.6044 - val_accuracy: 0.4355 - val_loss: 1.5664 - learning_rate: 0.0010
# Epoch 22/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.4290 - loss: 1.5937 - val_accuracy: 0.4532 - val_loss: 1.5508 - learning_rate: 0.0010
# Epoch 23/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4252 - loss: 1.5937 - val_accuracy: 0.4552 - val_loss: 1.5505 - learning_rate: 0.0010
# Epoch 24/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.4258 - loss: 1.5920 - val_accuracy: 0.4482 - val_loss: 1.5565 - learning_rate: 0.0010
# Epoch 25/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4293 - loss: 1.5917 - val_accuracy: 0.4457 - val_loss: 1.5703 - learning_rate: 0.0010
# Epoch 26/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4326 - loss: 1.5839 - val_accuracy: 0.4534 - val_loss: 1.5364 - learning_rate: 0.0010
# Epoch 27/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4357 - loss: 1.5749 - val_accuracy: 0.4543 - val_loss: 1.5474 - learning_rate: 0.0010
# Epoch 28/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4363 - loss: 1.5797 - val_accuracy: 0.4242 - val_loss: 1.6039 - learning_rate: 0.0010
# Epoch 29/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4211 - loss: 1.6080 - val_accuracy: 0.4409 - val_loss: 1.5633 - learning_rate: 0.0010
# Epoch 30/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step - accuracy: 0.4469 - loss: 1.5375 - val_accuracy: 0.4638 - val_loss: 1.5096 - learning_rate: 2.0000e-04
# Epoch 31/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4485 - loss: 1.5298 - val_accuracy: 0.4623 - val_loss: 1.5064 - learning_rate: 2.0000e-04
# Epoch 32/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4541 - loss: 1.5129 - val_accuracy: 0.4704 - val_loss: 1.4979 - learning_rate: 2.0000e-04
# Epoch 33/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.4567 - loss: 1.5104 - val_accuracy: 0.4664 - val_loss: 1.5075 - learning_rate: 2.0000e-04
# Epoch 34/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4555 - loss: 1.5080 - val_accuracy: 0.4671 - val_loss: 1.4924 - learning_rate: 2.0000e-04
# Epoch 35/35
# 1563/1563 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.4606 - loss: 1.5104 - val_accuracy: 0.4668 - val_loss: 1.4931 - learning_rate: 2.0000e-04

# %%
model_2.save_weights('myModel_adam.weights.h5')

# %%
history_dict_2 = h_2.history
history_dict_2.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
loss_values = history_dict_2['loss']
val_loss_values = history_dict_2['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict_2['accuracy']
val_acc_values = history_dict_2['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %%
loss, accuracy = model_2.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.504560  ;  loss = 1.413709

# %%
loss, accuracy = model_2.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.466800  ;  loss = 1.493072

# %%
# Predict the values from the validation dataset
Y_pred = model_2.predict(x_test)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes)
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step

# %% [markdown]
# # **Step 11: Inspecting output**

# %%
predicted = model_2.predict(x_test)
predicted_classes = np.argmax(predicted,axis=1)
correct_indices = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices = np.nonzero(predicted_classes != y_test)[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Number of true predictions: ", len(correct_indices))
print("Number of false predictions:", len(incorrect_indices))
# Out:
# Number of true predictions:  4668
# Number of false predictions: 5332

# %%
plt.rcParams['figure.figsize'] = (9,9)
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[correct], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(class_name[predicted_classes[correct]], class_name[y_test[correct]]))
    plt.subplots_adjust(wspace=1.2, hspace=0.01)

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[incorrect], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(class_name[predicted_classes[incorrect]], class_name[y_test[incorrect]]))
    plt.subplots_adjust(wspace=0.6, hspace=0.01)

# %% [markdown]
# # **Exercise**

# %% [markdown]
# ## Mnist Data
#
# ```
# The MNIST database contains 60,000 training images and 10,000 testing images taken from American Census Bureau employees and American high school students [4]. Therefore, in the second line, I have separated these two groups as train and test and also separated the labels and the images. x_train and x_test parts contain greyscale RGB codes (from 0 to 255) while y_train and y_test parts contains labels from 0 to 9 which represents which number they actually are.
# ![Example Mnist dataset](https://drive.google.com/open?id=1EjLwrpjtoCgo6kgdVgaMVc-ATxKnGmtn)
# ```

# %%
nb_epochs = 300
batch_size = 32
nb_classes = 10

# %% [markdown]
# ## Import Mnist Dataset

# %%
# To do
mnist = tf.keras.datasets.mnist
(x_train,y_train),(x_test,y_test) = mnist.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
mnist = tf.keras.datasets.mnist

# %%
(x_train,y_train),(x_test,y_test) = mnist.load_data()
y_train, y_test = y_train.reshape(y_train.shape[0]), y_test.reshape(y_test.shape[0])
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')
x_train, x_test = x_train / 255.0, x_test / 255.0

# %% [markdown]
# ## Create Model MLP

# %%
# To Do
input = Input(shape = (28,28))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
prediction = Dense(10, activation='softmax')(x)
model_3 = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
input = Input(shape = (28,28))
x = Flatten()(input)
x = Dense(512, activation='relu')(x)
x = Dropout(0.2)(x)
prediction = Dense(10, activation='softmax')(x)
model_3 = Model(inputs = input, outputs = prediction)

# %% [markdown]
# ## Add Early stopping, Reduce learning rate and compile

# %%
# To Do
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=10, min_lr=0.001)
model_3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
early_stopping = EarlyStopping(patience=10, verbose=1)
reduce_lr = ReduceLROnPlateau(monitor='val_loss', factor=0.2,patience=10, min_lr=0.001)
model_3.compile(optimizer='adam',loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %% [markdown]
# ## Fit model

# %%
# To Do
h_3 = model_3.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.8932 - loss: 0.3637 - val_accuracy: 0.9693 - val_loss: 0.1019 - learning_rate: 0.0010
# Epoch 2/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 9s 2ms/step - accuracy: 0.9709 - loss: 0.0979 - val_accuracy: 0.9743 - val_loss: 0.0829 - learning_rate: 0.0010
# Epoch 3/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9797 - loss: 0.0662 - val_accuracy: 0.9776 - val_loss: 0.0681 - learning_rate: 0.0010
# Epoch 4/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9836 - loss: 0.0514 - val_accuracy: 0.9786 - val_loss: 0.0695 - learning_rate: 0.0010
# Epoch 5/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.9794 - val_loss: 0.0691 - learning_rate: 0.0010
# Epoch 6/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0319 - val_accuracy: 0.9805 - val_loss: 0.0662 - learning_rate: 0.0010
# Epoch 7/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9897 - loss: 0.0299 - val_accuracy: 0.9795 - val_loss: 0.0724 - learning_rate: 0.0010
# Epoch 8/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 2ms/step - accuracy: 0.9913 - loss: 0.0263 - val_accuracy: 0.9821 - val_loss: 0.0707 - learning_rate: 0.0010
# Epoch 9/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9925 - loss: 0.0230 - val_accuracy: 0.9817 - val_loss: 0.0684 - learning_rate: 0.0010
# Epoch 10/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9925 - loss: 0.0210 - val_accuracy: 0.9815 - val_loss: 0.0741 - learning_rate: 0.0010
# Epoch 11/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9941 - loss: 0.0173 - val_accuracy: 0.9819 - val_loss: 0.0743 - learning_rate: 0.0010
# Epoch 12/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9947 - loss: 0.0159 - val_accuracy: 0.9818 - val_loss: 0.0886 - learning_rate: 0.0010
# Epoch 13/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9941 - loss: 0.0178 - val_accuracy: 0.9825 - val_loss: 0.0765 - learning_rate: 0.0010
# Epoch 14/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9939 - loss: 0.0159 - val_accuracy: 0.9816 - val_loss: 0.0822 - learning_rate: 0.0010
# Epoch 15/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9944 - loss: 0.0163 - val_accuracy: 0.9820 - val_loss: 0.0802 - learning_rate: 0.0010
# Epoch 16/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9950 - loss: 0.0142 - val_accuracy: 0.9834 - val_loss: 0.0852 - learning_rate: 0.0010
# Epoch 16: early stopping

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
h_3 = model_3.fit(x_train, y_train, batch_size=batch_size, epochs=nb_epochs,
    validation_data=(x_test, y_test),shuffle=True, callbacks = [early_stopping,reduce_lr])
# Out:
# Epoch 1/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9959 - loss: 0.0134 - val_accuracy: 0.9828 - val_loss: 0.0884 - learning_rate: 0.0010
# Epoch 2/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9952 - loss: 0.0150 - val_accuracy: 0.9826 - val_loss: 0.0799 - learning_rate: 0.0010
# Epoch 3/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9958 - loss: 0.0119 - val_accuracy: 0.9824 - val_loss: 0.0865 - learning_rate: 0.0010
# Epoch 4/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9968 - loss: 0.0089 - val_accuracy: 0.9835 - val_loss: 0.0902 - learning_rate: 0.0010
# Epoch 5/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9967 - loss: 0.0107 - val_accuracy: 0.9807 - val_loss: 0.1061 - learning_rate: 0.0010
# Epoch 6/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9961 - loss: 0.0117 - val_accuracy: 0.9820 - val_loss: 0.1063 - learning_rate: 0.0010
# Epoch 7/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.9792 - val_loss: 0.1186 - learning_rate: 0.0010
# Epoch 8/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9962 - loss: 0.0115 - val_accuracy: 0.9833 - val_loss: 0.1010 - learning_rate: 0.0010
# Epoch 9/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9963 - loss: 0.0107 - val_accuracy: 0.9843 - val_loss: 0.0964 - learning_rate: 0.0010
# Epoch 10/300
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 2ms/step - accuracy: 0.9971 - loss: 0.0096 - val_accuracy: 0.9825 - val_loss: 0.1090 - learning_rate: 0.0010
# Epoch 10: early stopping

# %% [markdown]
# ## Plot accuracy and loss

# %%
history_dict_3 = h_3.history
history_dict_3.keys()
# Out:
# dict_keys(['accuracy', 'loss', 'val_accuracy', 'val_loss', 'learning_rate'])

# %%
loss_values = history_dict_3['loss']
val_loss_values = history_dict_3['val_loss']
epochs = range(1, len(loss_values) + 1)

plt.plot(epochs, loss_values, 'bo')
plt.plot(epochs, val_loss_values, 'b+')
plt.title('Model loss')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Loss')
# Out:
# Text(0, 0.5, 'Loss')

# %%
acc_values = history_dict_3['accuracy']
val_acc_values = history_dict_3['val_accuracy']

plt.plot(epochs, acc_values, 'bo')
plt.plot(epochs, val_acc_values, 'b+')
plt.title('Model accuracy')
plt.legend(['Train', 'Test'], loc='upper left')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# ## Evaluate

# %%
# To Do.
loss, accuracy = model_3.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
loss, accuracy = model_3.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.999033  ;  loss = 0.002882
# Validation: accuracy = 0.982500  ;  loss = 0.108956

# %% [markdown]
# ### **Solution**
#
# Click below for a solution

# %%
loss, accuracy = model_3.evaluate(x_train,y_train, verbose=0)
print("Training: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Training: accuracy = 0.999033  ;  loss = 0.002882

# %%
loss, accuracy = model_3.evaluate(x_test, y_test, verbose=0)
print("Validation: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# Validation: accuracy = 0.982500  ;  loss = 0.108956

# %% [markdown]
# ## Confusion Matrix

# %%
# Predict the values from the validation dataset
Y_pred = model_3.predict(x_test)
# Convert predictions classes to one hot vectors
Y_pred_classes = np.argmax(Y_pred, axis = 1)
# compute the confusion matrix
confusion_mtx = confusion_matrix(y_test, Y_pred_classes)
# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(10))
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %% [markdown]
# ## Inspecting output

# %%
predicted = model_3.predict(x_test)
predicted_classes = np.argmax(predicted,axis=1)
correct_indices_2 = np.nonzero(predicted_classes == y_test)[0]
incorrect_indices_2 = np.nonzero(predicted_classes != y_test)[0]
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("Number of true predictions: ", len(correct_indices_2))
print("Number of false predictions:", len(incorrect_indices_2))
# Out:
# Number of true predictions:  9825
# Number of false predictions: 175

# %%
plt.rcParams['figure.figsize'] = (9,9)
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[correct], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
    plt.subplots_adjust(wspace=1.2, hspace=0.01)

# %%
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(x_test[incorrect], cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
    plt.subplots_adjust(wspace=0.6, hspace=0.01)
